# %% [markdown]
# ## Week 3 Group Assignment 2 (Individual)
# By: Jessica T. Lopez
#
# The 'Sex' dataset from Social Explorer, based on the latest ACS 5 year estimates, provides information on the 'male' and 'female' population in Los Angeles County for 2021. This dataset will help illustrate its distribution throughout Los Angeles County and possibly help explain any correlation between sex and traffic incidents.

# %% [markdown]
# ### Importing Data

# %% [markdown]
# I'll start by importing pandas to explore data from Social Explorer.

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# I Will now import 'Sex' Social Explorer data for Los Angeles County.

# %%
df = pd.read_csv('Census_Data_Sex.csv')

# %% [markdown]
# ### Exploring the Data

# %% [markdown]
# First, I will be check the size of the data by using the shape function.

# %%
df.shape
# Out:
# (2498, 60)

# %% [markdown]
# There are 2498 rows and 60 columns in this dataset.

# %%
# Next, sample the first ten rows.
df.head(10)
# Out:
#      Geo_FIPS                                          Geo_QName Geo_FILEID  \
# 0  6037101110  Census Tract 1011.10, Los Angeles County, Cali...      ACSSF
# 1  6037101122  Census Tract 1011.22, Los Angeles County, Cali...      ACSSF
# 2  6037101220  Census Tract 1012.20, Los Angeles County, Cali...      ACSSF
# 3  6037101221  Census Tract 1012.21, Los Angeles County, Cali...      ACSSF
# 4  6037101222  Census Tract 1012.22, Los Angeles County, Cali...      ACSSF
# 5  6037101300  Census Tract 1013, Los Angeles County, California      ACSSF
# 6  6037101400  Census Tract 1014, Los Angeles County, California      ACSSF
# 7  6037102103  Census Tract 1021.03, Los Angeles County, Cali...      ACSSF
# 8  6037102104  Census Tract 1021.04, Los Angeles County, Cali...      ACSSF
# 9  6037102105  Census Tract 1021.05, Los Angeles County, Cali...      ACSSF
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO  Geo_US  Geo_REGION  \
# 0         ca         140            0          4200     NaN         NaN
# 1         ca         140            0          4201     NaN         NaN
# 2         ca         140            0          4202     NaN         NaN
# 3         ca         140            0          4203     NaN         NaN
# 4         ca         140            0          4204     NaN         NaN
# 5         ca         140            0          4205     NaN         NaN
# 6         ca         140            0          4206     NaN         NaN
# 7         ca         140            0          4207     NaN         NaN
# 8         ca         140            0          4208     NaN         NaN
# 9         ca         140            0          4209     NaN         NaN
#
#    Geo_DIVISION  ...           Geo_GEOID              Geo_NAME  Geo_BTTR  \
# 0           NaN  ...  14000US06037101110  Census Tract 1011.10       NaN
# 1           NaN  ...  14000US06037101122  Census Tract 1011.22       NaN
# 2           NaN  ...  14000US06037101220  Census Tract 1012.20       NaN
# 3           NaN  ...  14000US06037101221  Census Tract 1012.21       NaN
# 4           NaN  ...  14000US06037101222  Census Tract 1012.22       NaN
# 5           NaN  ...  14000US06037101300     Census Tract 1013       NaN
# 6           NaN  ...  14000US06037101400     Census Tract 1014       NaN
# 7           NaN  ...  14000US06037102103  Census Tract 1021.03       NaN
# 8           NaN  ...  14000US06037102104  Census Tract 1021.04       NaN
# 9           NaN  ...  14000US06037102105  Census Tract 1021.05       NaN
#
#    Geo_BTBG  Geo_PLACESE  SE_A02001_001  SE_A02001_002  SE_A02001_003  \
# 0       NaN          NaN           3879           1944           1935
# 1       NaN          NaN           4247           2066           2181
# 2       NaN          NaN           3583           1692           1891
# 3       NaN          NaN           3723           1954           1769
# 4       NaN          NaN           2690           1174           1516
# 5       NaN          NaN           4068           1921           2147
# 6       NaN          NaN           3372           1610           1762
# 7       NaN          NaN           1767            813            954
# 8       NaN          NaN           4003           1733           2270
# 9       NaN          NaN           1674            773            901
#
#    PCT_SE_A02001_002  PCT_SE_A02001_003
# 0              50.12              49.88
# 1              48.65              51.35
# 2              47.22              52.78
# 3              52.48              47.52
# 4              43.64              56.36
# 5              47.22              52.78
# 6              47.75              52.25
# 7              46.01              53.99
# 8              43.29              56.71
# 9              46.18              53.82
#
# [10 rows x 60 columns]

# %%
# Will be looking at the data type using the .info function
# Will use the argument 'verbose=true, show true counts'
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2498 entries, 0 to 2497
# Data columns (total 60 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           2498 non-null   int64
#  1   Geo_QName          2498 non-null   object
#  2   Geo_FILEID         2498 non-null   object
#  3   Geo_STUSAB         2498 non-null   object
#  4   Geo_SUMLEV         2498 non-null   int64
#  5   Geo_GEOCOMP        2498 non-null   int64
#  6   Geo_LOGRECNO       2498 non-null   int64
#  7   Geo_US             0 non-null      float64
#  8   Geo_REGION         0 non-null      float64
#  9   Geo_DIVISION       0 non-null      float64
#  10  Geo_STATECE        0 non-null      float64
#  11  Geo_STATE          2498 non-null   int64
#  12  Geo_COUNTY         2498 non-null   int64
#  13  Geo_COUSUB         0 non-null      float64
#  14  Geo_PLACE          0 non-null      float64
#  15  Geo_TRACT          2498 non-null   int64
#  16  Geo_BLKGRP         0 non-null      float64
#  17  Geo_CONCIT         0 non-null      float64
#  18  Geo_AIANHH         0 non-null      float64
#  19  Geo_AIANHHFP       0 non-null      float64
#  20  Geo_AIHHTLI        0 non-null      float64
#  21  Geo_AITSCE         0 non-null      float64
#  22  Geo_AITS           0 non-null      float64
#  23  Geo_ANRC           0 non-null      float64
#  24  Geo_CBSA           0 non-null      float64
#  25  Geo_CSA            0 non-null      float64
#  26  Geo_METDIV         0 non-null      float64
#  27  Geo_MACC           0 non-null      float64
#  28  Geo_MEMI           0 non-null      float64
#  29  Geo_NECTA          0 non-null      float64
#  30  Geo_CNECTA         0 non-null      float64
#  31  Geo_NECTADIV       0 non-null      float64
#  32  Geo_UA             0 non-null      float64
#  33  Geo_UACP           0 non-null      float64
#  34  Geo_CDCURR         0 non-null      float64
#  35  Geo_SLDU           0 non-null      float64
#  36  Geo_SLDL           0 non-null      float64
#  37  Geo_VTD            0 non-null      float64
#  38  Geo_ZCTA3          0 non-null      float64
#  39  Geo_ZCTA5          0 non-null      float64
#  40  Geo_SUBMCD         0 non-null      float64
#  41  Geo_SDELM          0 non-null      float64
#  42  Geo_SDSEC          0 non-null      float64
#  43  Geo_SDUNI          0 non-null      float64
#  44  Geo_UR             0 non-null      float64
#  45  Geo_PCI            0 non-null      float64
#  46  Geo_TAZ            0 non-null      float64
#  47  Geo_UGA            0 non-null      float64
#  48  Geo_PUMA5          0 non-null      float64
#  49  Geo_PUMA1          0 non-null      float64
#  50  Geo_GEOID          2498 non-null   object
#  51  Geo_NAME           2498 non-null   object
#  52  Geo_BTTR           0 non-null      float64
#  53  Geo_BTBG           0 non-null      float64
#  54  Geo_PLACESE        0 non-null      float64
#  55  SE_A02001_001      2498 non-null   int64
#  56  SE_A02001_002      2498 non-null   int64
#  57  SE_A02001_003      2498 non-null   int64
#  58  PCT_SE_A02001_002  2478 non-null   float64
#  59  PCT_SE_A02001_003  2478 non-null   float64
# dtypes: float64(45), int64(10), object(5)
# memory usage: 1.1+ MB

# %%
# got the dtypes for the columns.

# %%
df.Geo_FIPS.head()
# Out:
# 0    6037101110
# 1    6037101122
# 2    6037101220
# 3    6037101221
# 4    6037101222
# Name: Geo_FIPS, dtype: int64

# %% [markdown]
# As per lab the leading zero's are important. Now I have to re-inport data to specify the Geo_FIPS column as a string.

# %%
df = pd.read_csv(
    'Census_Data_Sex.csv',
    dtype=
    {
        'Geo_FIPS':str,
        'Geo_STATE':str,
        'Geo_COUNTY': str
    }
)

# %%
# now running the first ten columns once more
df.head(10)
# Out:
#       Geo_FIPS                                          Geo_QName Geo_FILEID  \
# 0  06037101110  Census Tract 1011.10, Los Angeles County, Cali...      ACSSF
# 1  06037101122  Census Tract 1011.22, Los Angeles County, Cali...      ACSSF
# 2  06037101220  Census Tract 1012.20, Los Angeles County, Cali...      ACSSF
# 3  06037101221  Census Tract 1012.21, Los Angeles County, Cali...      ACSSF
# 4  06037101222  Census Tract 1012.22, Los Angeles County, Cali...      ACSSF
# 5  06037101300  Census Tract 1013, Los Angeles County, California      ACSSF
# 6  06037101400  Census Tract 1014, Los Angeles County, California      ACSSF
# 7  06037102103  Census Tract 1021.03, Los Angeles County, Cali...      ACSSF
# 8  06037102104  Census Tract 1021.04, Los Angeles County, Cali...      ACSSF
# 9  06037102105  Census Tract 1021.05, Los Angeles County, Cali...      ACSSF
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO  Geo_US  Geo_REGION  \
# 0         ca         140            0          4200     NaN         NaN
# 1         ca         140            0          4201     NaN         NaN
# 2         ca         140            0          4202     NaN         NaN
# 3         ca         140            0          4203     NaN         NaN
# 4         ca         140            0          4204     NaN         NaN
# 5         ca         140            0          4205     NaN         NaN
# 6         ca         140            0          4206     NaN         NaN
# 7         ca         140            0          4207     NaN         NaN
# 8         ca         140            0          4208     NaN         NaN
# 9         ca         140            0          4209     NaN         NaN
#
#    Geo_DIVISION  ...           Geo_GEOID              Geo_NAME Geo_BTTR  \
# 0           NaN  ...  14000US06037101110  Census Tract 1011.10      NaN
# 1           NaN  ...  14000US06037101122  Census Tract 1011.22      NaN
# 2           NaN  ...  14000US06037101220  Census Tract 1012.20      NaN
# 3           NaN  ...  14000US06037101221  Census Tract 1012.21      NaN
# 4           NaN  ...  14000US06037101222  Census Tract 1012.22      NaN
# 5           NaN  ...  14000US06037101300     Census Tract 1013      NaN
# 6           NaN  ...  14000US06037101400     Census Tract 1014      NaN
# 7           NaN  ...  14000US06037102103  Census Tract 1021.03      NaN
# 8           NaN  ...  14000US06037102104  Census Tract 1021.04      NaN
# 9           NaN  ...  14000US06037102105  Census Tract 1021.05      NaN
#
#    Geo_BTBG  Geo_PLACESE  SE_A02001_001  SE_A02001_002  SE_A02001_003  \
# 0       NaN          NaN           3879           1944           1935
# 1       NaN          NaN           4247           2066           2181
# 2       NaN          NaN           3583           1692           1891
# 3       NaN          NaN           3723           1954           1769
# 4       NaN          NaN           2690           1174           1516
# 5       NaN          NaN           4068           1921           2147
# 6       NaN          NaN           3372           1610           1762
# 7       NaN          NaN           1767            813            954
# 8       NaN          NaN           4003           1733           2270
# 9       NaN          NaN           1674            773            901
#
#    PCT_SE_A02001_002  PCT_SE_A02001_003
# 0              50.12              49.88
# 1              48.65              51.35
# 2              47.22              52.78
# 3              52.48              47.52
# 4              43.64              56.36
# 5              47.22              52.78
# 6              47.75              52.25
# 7              46.01              53.99
# 8              43.29              56.71
# 9              46.18              53.82
#
# [10 rows x 60 columns]

# %%
# now all Geo_FIPS have a leading zero

# %% [markdown]
# Now, I will be re-running data to make sure the dataframe has the
# correct datatype.

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2498 entries, 0 to 2497
# Data columns (total 60 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           2498 non-null   object
#  1   Geo_QName          2498 non-null   object
#  2   Geo_FILEID         2498 non-null   object
#  3   Geo_STUSAB         2498 non-null   object
#  4   Geo_SUMLEV         2498 non-null   int64
#  5   Geo_GEOCOMP        2498 non-null   int64
#  6   Geo_LOGRECNO       2498 non-null   int64
#  7   Geo_US             0 non-null      float64
#  8   Geo_REGION         0 non-null      float64
#  9   Geo_DIVISION       0 non-null      float64
#  10  Geo_STATECE        0 non-null      float64
#  11  Geo_STATE          2498 non-null   object
#  12  Geo_COUNTY         2498 non-null   object
#  13  Geo_COUSUB         0 non-null      float64
#  14  Geo_PLACE          0 non-null      float64
#  15  Geo_TRACT          2498 non-null   int64
#  16  Geo_BLKGRP         0 non-null      float64
#  17  Geo_CONCIT         0 non-null      float64
#  18  Geo_AIANHH         0 non-null      float64
#  19  Geo_AIANHHFP       0 non-null      float64
#  20  Geo_AIHHTLI        0 non-null      float64
#  21  Geo_AITSCE         0 non-null      float64
#  22  Geo_AITS           0 non-null      float64
#  23  Geo_ANRC           0 non-null      float64
#  24  Geo_CBSA           0 non-null      float64
#  25  Geo_CSA            0 non-null      float64
#  26  Geo_METDIV         0 non-null      float64
#  27  Geo_MACC           0 non-null      float64
#  28  Geo_MEMI           0 non-null      float64
#  29  Geo_NECTA          0 non-null      float64
#  30  Geo_CNECTA         0 non-null      float64
#  31  Geo_NECTADIV       0 non-null      float64
#  32  Geo_UA             0 non-null      float64
#  33  Geo_UACP           0 non-null      float64
#  34  Geo_CDCURR         0 non-null      float64
#  35  Geo_SLDU           0 non-null      float64
#  36  Geo_SLDL           0 non-null      float64
#  37  Geo_VTD            0 non-null      float64
#  38  Geo_ZCTA3          0 non-null      float64
#  39  Geo_ZCTA5          0 non-null      float64
#  40  Geo_SUBMCD         0 non-null      float64
#  41  Geo_SDELM          0 non-null      float64
#  42  Geo_SDSEC          0 non-null      float64
#  43  Geo_SDUNI          0 non-null      float64
#  44  Geo_UR             0 non-null      float64
#  45  Geo_PCI            0 non-null      float64
#  46  Geo_TAZ            0 non-null      float64
#  47  Geo_UGA            0 non-null      float64
#  48  Geo_PUMA5          0 non-null      float64
#  49  Geo_PUMA1          0 non-null      float64
#  50  Geo_GEOID          2498 non-null   object
#  51  Geo_NAME           2498 non-null   object
#  52  Geo_BTTR           0 non-null      float64
#  53  Geo_BTBG           0 non-null      float64
#  54  Geo_PLACESE        0 non-null      float64
#  55  SE_A02001_001      2498 non-null   int64
#  56  SE_A02001_002      2498 non-null   int64
#  57  SE_A02001_003      2498 non-null   int64
#  58  PCT_SE_A02001_002  2478 non-null   float64
#  59  PCT_SE_A02001_003  2478 non-null   float64
# dtypes: float64(45), int64(7), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Cleaning up the Data

# %% [markdown]
# As I was going thrgouth the data there were many columns without data.
# Now its time to eliminate all empty columns.

# %%
# To do so I will use the .columns,.isna,.all commands.
df.columns[df.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_STATECE',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITSCE',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_UACP',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_VTD',
#  'Geo_ZCTA3',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_TAZ',
#  'Geo_UGA',
#  'Geo_PUMA5',
#  'Geo_PUMA1',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PLACESE']

# %%
# the columns listed above now have to be eliminated.
# I will use the follwoing command to do so:
df = df.dropna(axis=1, how= 'all')

# %%
# Will now check to see if these columns were dropped.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2498 entries, 0 to 2497
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           2498 non-null   object
#  1   Geo_QName          2498 non-null   object
#  2   Geo_FILEID         2498 non-null   object
#  3   Geo_STUSAB         2498 non-null   object
#  4   Geo_SUMLEV         2498 non-null   int64
#  5   Geo_GEOCOMP        2498 non-null   int64
#  6   Geo_LOGRECNO       2498 non-null   int64
#  7   Geo_STATE          2498 non-null   object
#  8   Geo_COUNTY         2498 non-null   object
#  9   Geo_TRACT          2498 non-null   int64
#  10  Geo_GEOID          2498 non-null   object
#  11  Geo_NAME           2498 non-null   object
#  12  SE_A02001_001      2498 non-null   int64
#  13  SE_A02001_002      2498 non-null   int64
#  14  SE_A02001_003      2498 non-null   int64
#  15  PCT_SE_A02001_002  2478 non-null   float64
#  16  PCT_SE_A02001_003  2478 non-null   float64
# dtypes: float64(2), int64(7), object(8)
# memory usage: 331.9+ KB

# %%
# have to reinspect data
df.head()
# Out:
#       Geo_FIPS                                          Geo_QName Geo_FILEID  \
# 0  06037101110  Census Tract 1011.10, Los Angeles County, Cali...      ACSSF
# 1  06037101122  Census Tract 1011.22, Los Angeles County, Cali...      ACSSF
# 2  06037101220  Census Tract 1012.20, Los Angeles County, Cali...      ACSSF
# 3  06037101221  Census Tract 1012.21, Los Angeles County, Cali...      ACSSF
# 4  06037101222  Census Tract 1012.22, Los Angeles County, Cali...      ACSSF
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO Geo_STATE Geo_COUNTY  \
# 0         ca         140            0          4200        06        037
# 1         ca         140            0          4201        06        037
# 2         ca         140            0          4202        06        037
# 3         ca         140            0          4203        06        037
# 4         ca         140            0          4204        06        037
#
#    Geo_TRACT           Geo_GEOID              Geo_NAME  SE_A02001_001  \
# 0     101110  14000US06037101110  Census Tract 1011.10           3879
# 1     101122  14000US06037101122  Census Tract 1011.22           4247
# 2     101220  14000US06037101220  Census Tract 1012.20           3583
# 3     101221  14000US06037101221  Census Tract 1012.21           3723
# 4     101222  14000US06037101222  Census Tract 1012.22           2690
#
#    SE_A02001_002  SE_A02001_003  PCT_SE_A02001_002  PCT_SE_A02001_003
# 0           1944           1935              50.12              49.88
# 1           2066           2181              48.65              51.35
# 2           1692           1891              47.22              52.78
# 3           1954           1769              52.48              47.52
# 4           1174           1516              43.64              56.36

# %%
# it is looking much better now that all the empty columns have been eliminated.

# %% [markdown]
# After going through the data dictionary I decided to keep
# FIPS, and percentage of male/female population.

# %%
columns_to_keep = ['Geo_FIPS', 
                   'SE_A02001_001',
                   'SE_A02001_002',
                   'SE_A02001_003',]
#add it to new data frame
df2 = df[columns_to_keep]

# %% [markdown]
# ### Renaming the Columns

# %% [markdown]
# I will rename the columns I want to keep, which are: FIPS, Total population, male and female.

# %%
columns = list (df2)
columns
# its the same list created in the columns to keep cell above
# Out:
# ['Geo_FIPS', 'SE_A02001_001', 'SE_A02001_002', 'SE_A02001_003']

# %% [markdown]
# I have copied the values above in the cell below, replacing them with names of my choice.

# %%
df2.columns = ['FIPS','TotalPop', 'Male', 'Female']

# %%
# checking dataset for new names/titles
df2.sample(4)
# Out:
#              FIPS  TotalPop  Male  Female
# 1390  06037430502      6514  2838    3676
# 1829  06037543703      3864  1875    1989
# 2438  06037920121     10391  5567    4824
# 449   06037189801      1766   820     946

# %% [markdown]
# ### Simple Stats and Plots

# %%
# checking total population
df2['TotalPop'].head()
# Out:
# 0    3879
# 1    4247
# 2    3583
# 3    3723
# 4    2690
# Name: TotalPop, dtype: int64

# %%
# What is the population mean?
df2['TotalPop'].mean()
# Out:
# 4011.062850280224

# %%
# What is the median?
df2['TotalPop'].median()
# Out:
# 3933.0

# %%
# Now some stats
df2['TotalPop'].describe()
# Out:
# count     2498.00000
# mean      4011.06285
# std       1470.99188
# min          0.00000
# 25%       2993.25000
# 50%       3933.00000
# 75%       4954.00000
# max      13830.00000
# Name: TotalPop, dtype: float64

# %%
#plotting as a histogram with 50 bins
df2['TotalPop'].plot.hist(bins=50)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
# using box plot
df2.boxplot(column=['TotalPop'])
# Out:
# <AxesSubplot: >

# %%
# using a scatter plot
df2.plot.scatter(x='Male', y='Female')
# Out:
# <AxesSubplot: xlabel='Male', ylabel='Female'>

# %% [markdown]
# ### Sorting

# %% [markdown]
# Now, I will be looking for the most populated census tract.

# %%
df_sorted=df2.sort_values(by='TotalPop',ascending = False)

# %%
#display a few columns of data
df_sorted[['FIPS','TotalPop']].head(10)
# Out:
#              FIPS  TotalPop
# 938   06037265301     13830
# 580   06037206020     10614
# 2438  06037920121     10391
# 1028  06037275604      9814
# 2278  06037702900      9355
# 2406  06037920028      9158
# 1604  06037502303      8883
# 69    06037108202      8776
# 2417  06037920043      8468
# 1207  06037401707      8464

# %%
# now plotting for total population
df_sorted.head(10).plot.bar(x='FIPS', y='TotalPop')
# Out:
# <AxesSubplot: xlabel='FIPS'>

# %%
# Now cleaning it up and adding titles 
df_sorted.head(10).plot.barh(x='FIPS',
                             y='TotalPop',
                             title='Top 10 Census Tracts with Highest Population in Los Angeles County in 2021',
                             color='deeppink')
# Out:
# <AxesSubplot: title={'center': 'Top 10 Census Tracts with Highest Population in Los Angeles County in 2021'}, ylabel='FIPS'>

# %% [markdown]
# Now I want to check which tracts have the highest Male and Female populations.

# %%
df_sorted=df2.sort_values(by='Male',ascending = False)

# %%
#display a few columns of data
df_sorted[['FIPS','Male']].head(10)
# Out:
#              FIPS   Male
# 580   06037206020  10299
# 2439  06037920200   5838
# 938   06037265301   5581
# 2438  06037920121   5567
# 1028  06037275604   4819
# 2334  06037901003   4817
# 2406  06037920028   4796
# 2278  06037702900   4660
# 2411  06037920035   4561
# 1604  06037502303   4367

# %%
# now plotting for male population
df_sorted.head(10).plot.bar(x='FIPS', y='Male')
# Out:
# <AxesSubplot: xlabel='FIPS'>

# %%
# Now cleaning it up and adding titles 
df_sorted.head(10).plot.barh(x='FIPS',
                             y='Male',
                             title='Top 10 Census Tracts with Highest Male Population in Los Angeles County in 2021',
                             color='deeppink')
# Out:
# <AxesSubplot: title={'center': 'Top 10 Census Tracts with Highest Male Population in Los Angeles County in 2021'}, ylabel='FIPS'>

# %%
# Now sorting for Female population
df_sorted=df2.sort_values(by='Female',ascending = False)

# %%
#display a few columns of data
df_sorted[['FIPS','Female']].head(10)
# Out:
#              FIPS  Female
# 938   06037265301    8249
# 1028  06037275604    4995
# 2438  06037920121    4824
# 2278  06037702900    4695
# 1604  06037502303    4516
# 1207  06037401707    4506
# 69    06037108202    4501
# 1309  06037406103    4471
# 1189  06037400605    4375
# 2406  06037920028    4362

# %%
# now plotting for Female population
df_sorted.head(10).plot.bar(x='FIPS', y='Female')
# Out:
# <AxesSubplot: xlabel='FIPS'>

# %%
# Now cleaning it up and adding titles 
df_sorted.head(10).plot.barh(x='FIPS',
                             y='Female',
                             title='Top 10 Census Tracts with Highest Female Population in Los Angeles County in 2021',
                             color='deeppink')
# Out:
# <AxesSubplot: title={'center': 'Top 10 Census Tracts with Highest Female Population in Los Angeles County in 2021'}, ylabel='FIPS'>

# %% [markdown]
# ### Filtering and Subsetting Data

# %% [markdown]
# First, filtering for census tracts without people

# %%
# subsetting the data to see the data per row
df2[df2['TotalPop']==0]
# Out:
#              FIPS  TotalPop  Male  Female
# 2459  06037980001         0     0       0
# 2460  06037980002         0     0       0
# 2461  06037980003         0     0       0
# 2462  06037980004         0     0       0
# 2463  06037980005         0     0       0
# 2464  06037980006         0     0       0
# 2465  06037980007         0     0       0
# 2471  06037980013         0     0       0
# 2476  06037980018         0     0       0
# 2478  06037980020         0     0       0
# 2480  06037980022         0     0       0
# 2481  06037980023         0     0       0
# 2485  06037980028         0     0       0
# 2486  06037980030         0     0       0
# 2492  06037980037         0     0       0
# 2493  06037980038         0     0       0
# 2494  06037980039         0     0       0
# 2495  06037990100         0     0       0
# 2496  06037990200         0     0       0
# 2497  06037990300         0     0       0

# %%
# now creating a new variable for census tracts with zero population
df_no_pop=df2[df2['TotalPop']==0]

# %%
# how many records for census tracts with zero population
print('There are ' + str(len(df_no_pop)) + 'census tracts with no people in them')
# Out:
# There are 20census tracts with no people in them

# %%
# now displaying census tracts without people
df_no_pop[['FIPS','TotalPop']]
# Out:
#              FIPS  TotalPop
# 2459  06037980001         0
# 2460  06037980002         0
# 2461  06037980003         0
# 2462  06037980004         0
# 2463  06037980005         0
# 2464  06037980006         0
# 2465  06037980007         0
# 2471  06037980013         0
# 2476  06037980018         0
# 2478  06037980020         0
# 2480  06037980022         0
# 2481  06037980023         0
# 2485  06037980028         0
# 2486  06037980030         0
# 2492  06037980037         0
# 2493  06037980038         0
# 2494  06037980039         0
# 2495  06037990100         0
# 2496  06037990200         0
# 2497  06037990300         0

# %% [markdown]
# ### Finally, time for Maps!

# %% [markdown]
# Now, I will start by importing geopandas.

# %%
import geopandas as gpd

# %%
# since our data is based in LA I will import LA Census tracts
tracts=gpd.read_file('Census_Tracts_2020.geojson')
tracts.head()
# Out:
#    OBJECTID    CT20    LABEL   ShapeSTArea  ShapeSTLength  \
# 0         1  101110  1011.10  1.229562e+07   15083.854287
# 1         2  101122  1011.22  2.845774e+07   31671.455844
# 2         3  101220  1012.20  7.522093e+06   12698.783810
# 3         4  101221  1012.21  3.812000e+06    9161.710543
# 4         5  101222  1012.22  3.191371e+06    9980.600461
#
#                                             geometry
# 0  POLYGON ((-118.28491 34.25948, -118.28492 34.2...
# 1  POLYGON ((-118.29015 34.27417, -118.29015 34.2...
# 2  POLYGON ((-118.28100 34.25592, -118.28198 34.2...
# 3  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  POLYGON ((-118.28594 34.25405, -118.28594 34.2...

# %%
# time to plot
tracts.plot(figsize=(12,10))
# Out:
# <AxesSubplot: >

# %%
# want to more about dataset
tracts.info(verbose=True, show_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2495 entries, 0 to 2494
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OBJECTID       2495 non-null   int64
#  1   CT20           2495 non-null   object
#  2   LABEL          2495 non-null   object
#  3   ShapeSTArea    2495 non-null   float64
#  4   ShapeSTLength  2495 non-null   float64
#  5   geometry       2495 non-null   geometry
# dtypes: float64(2), geometry(1), int64(1), object(2)
# memory usage: 117.1+ KB

# %%
# will only need FIPS and geometry, so I need to subset the data
tracts=tracts[['CT20','geometry']]
tracts.head()
# Out:
#      CT20                                           geometry
# 0  101110  POLYGON ((-118.28491 34.25948, -118.28492 34.2...
# 1  101122  POLYGON ((-118.29015 34.27417, -118.29015 34.2...
# 2  101220  POLYGON ((-118.28100 34.25592, -118.28198 34.2...
# 3  101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  101222  POLYGON ((-118.28594 34.25405, -118.28594 34.2...

# %%
# Now I will create a FIPS column
tracts['FIPS'] ='06' + '037' + tracts['CT20']

# %%
# Now checking
tracts.head()
# Out:
#      CT20                                           geometry         FIPS
# 0  101110  POLYGON ((-118.28491 34.25948, -118.28492 34.2...  06037101110
# 1  101122  POLYGON ((-118.29015 34.27417, -118.29015 34.2...  06037101122
# 2  101220  POLYGON ((-118.28100 34.25592, -118.28198 34.2...  06037101220
# 3  101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...  06037101221
# 4  101222  POLYGON ((-118.28594 34.25405, -118.28594 34.2...  06037101222

# %% [markdown]
# ### Merging Data

# %% [markdown]
# Will now be joining census tract data with Male/Female population data.

# %%
# creating a new dataframe based on the join
tracts_sex=tracts.merge(df2,on="FIPS")

# %%
# checking on how it looks now
tracts_sex.head()
# Out:
#      CT20                                           geometry         FIPS  \
# 0  101110  POLYGON ((-118.28491 34.25948, -118.28492 34.2...  06037101110
# 1  101122  POLYGON ((-118.29015 34.27417, -118.29015 34.2...  06037101122
# 2  101220  POLYGON ((-118.28100 34.25592, -118.28198 34.2...  06037101220
# 3  101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...  06037101221
# 4  101222  POLYGON ((-118.28594 34.25405, -118.28594 34.2...  06037101222
#
#    TotalPop  Male  Female
# 0      3879  1944    1935
# 1      4247  2066    2181
# 2      3583  1692    1891
# 3      3723  1954    1769
# 4      2690  1174    1516

# %% [markdown]
# ### Chloropleth Maps

# %% [markdown]
# Will now create chloropleth maps in geopandas.

# %% [markdown]
# #### Maps for Male Population

# %%
tracts_sex.plot(figsize=(12,10),
                 column='Male',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <AxesSubplot: >

# %%
tracts_sex.plot(figsize=(12,10),
                 column='Male',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <AxesSubplot: >

# %%
tracts_sex.plot(figsize=(12,10),
                 column='Male',
                 legend=True, 
                 scheme='quantiles')
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### Maps for Female Population

# %%
tracts_sex.plot(figsize=(12,10),
                 column='Female',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <AxesSubplot: >

# %%
tracts_sex.plot(figsize=(12,10),
                 column='Female',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <AxesSubplot: >

# %%
tracts_sex.plot(figsize=(12,10),
                 column='Female',
                 legend=True, 
                 scheme='quantiles')
# Out:
# <AxesSubplot: >

# %%
tracts_sex['PCT_Black'] = tracts_sex['Male']/tracts_sex['TotalPop']*100
tracts_sex['PCT_White'] = tracts_sex['Female']/tracts_sex['TotalPop']*100

# %%
tracts_sex.plot(figsize=(12,10),
                 column='Male',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <AxesSubplot: >

# %%
tracts_sex.plot(figsize=(12,10),
                 column='Female',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <AxesSubplot: >

# %%
m.save('sex.html')
